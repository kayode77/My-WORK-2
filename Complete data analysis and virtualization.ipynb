# %%
import pandas as pd
import seaborn as sns
Tips = sns.load_dataset('tips')
Tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
Tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
Tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
plt.figure(figsize=(10, 3.5))
sns.pairplot(Tips, hue='sex')

# %%
# People that are Females:
Tips = sns.load_dataset('tips')
A=Tips[Tips.sex.isin(['Female'])]
A
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
# People that are Males:
Tips = sns.load_dataset('tips')
B=Tips[Tips.sex.isin(['Male'])]
B
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
# Females that smokes :
C=Tips[(Tips.sex =='Female') & (Tips.smoker =='Yes')]
C
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# ...

# %%
# Females that do not smokes :
D=Tips[(Tips.sex =='Female') & (Tips.smoker =='No')]
D
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 33        20.69  2.45  Female     No   Sat  Dinner     4
# 37        16.93  3.07  Female     No   Sat  Dinner     3
# 51        10.29  2.60  Female     No   Sun  Dinner     2
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# ...

# %%
# Males that smokes :
E=Tips[(Tips.sex =='Male') & (Tips.smoker =='Yes')]
E
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 56        38.01   3.00  Male    Yes   Sat  Dinner     4
# 58        11.24   1.76  Male    Yes   Sat  Dinner     2
# 60        20.29   3.21  Male    Yes   Sat  Dinner     2
# 61        13.81   2.00  Male    Yes   Sat  Dinner     2
# 62        11.02   1.98  Male    Yes   Sat  Dinner     2
# 63        18.29   3.76  Male    Yes   Sat  Dinner     4
# 69        15.01   2.09  Male    Yes   Sat  Dinner     2
# 76        17.92   3.08  Male    Yes   Sat  Dinner     2
# 80        19.44   3.00  Male    Yes  Thur   Lunch     2
# 83        32.68   5.00  Male    Yes  Thur   Lunch     2
# 90        28.97   3.00  Male    Yes   Fri  Dinner     2
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4
# 96        27.28   4.00  Male    Yes   Fri  Dinner     2
# 97        12.03   1.50  Male    Yes   Fri  Dinner     2
# 98        21.01   3.00  Male    Yes   Fri  Dinner     2
# 105       15.36   1.64  Male    Yes   Sat  Dinner     2
# ...

# %%
# Males that do not smokes :
F=Tips[(Tips.sex =='Male') & (Tips.smoker =='No')]
F
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 232       11.61  3.39  Male     No  Sat  Dinner     2
# 233       10.77  1.47  Male     No  Sat  Dinner     2
# 235       10.07  1.25  Male     No  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [97 rows x 7 columns]

# %%
Tips.smoker.unique()
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
Tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
Tips.day.unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
Tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
Tips.time.unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
Tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
# Females and males that smoke :
G=Tips[(Tips.smoker =='Yes')]
G
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
# Females and males that do not smoke :
H=Tips[(Tips.smoker =='No')]
H
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
I=Tips[(Tips.smoker =='Yes')][['sex','smoker']]
I
# Out:
#         sex smoker
# 56     Male    Yes
# 58     Male    Yes
# 60     Male    Yes
# 61     Male    Yes
# 62     Male    Yes
# ..      ...    ...
# 234    Male    Yes
# 236    Male    Yes
# 237    Male    Yes
# 240  Female    Yes
# 241    Male    Yes
#
# [93 rows x 2 columns]

# %%
J=Tips[(Tips.smoker =='No')][['sex','smoker']]
J
# Out:
#         sex smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# ..      ...    ...
# 235    Male     No
# 238  Female     No
# 239    Male     No
# 242    Male     No
# 243  Female     No
#
# [151 rows x 2 columns]

# %%
# Female smokers on Sunday
Tips[(Tips.sex =='Female') & (Tips.smoker =='Yes') & (Tips.day =='Sun')]
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 164       17.51  3.0  Female    Yes  Sun  Dinner     2
# 178        9.60  4.0  Female    Yes  Sun  Dinner     2
# 186       20.90  3.5  Female    Yes  Sun  Dinner     3
# 188       18.15  3.5  Female    Yes  Sun  Dinner     3

# %%
# Female smokers on Saturday
Tips[(Tips.sex =='Female') & (Tips.smoker =='Yes') & (Tips.day =='Sat')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 103       22.42  3.48  Female    Yes  Sat  Dinner     2
# 109       14.31  4.00  Female    Yes  Sat  Dinner     2
# 168       10.59  1.61  Female    Yes  Sat  Dinner     2
# 169       10.63  2.00  Female    Yes  Sat  Dinner     2
# 209       12.76  2.23  Female    Yes  Sat  Dinner     2
# 213       13.27  2.50  Female    Yes  Sat  Dinner     2
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3
# 215       12.90  1.10  Female    Yes  Sat  Dinner     2
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2

# %%
# Female smokers on Friday
Tips[(Tips.sex =='Female') & (Tips.smoker =='Yes') & (Tips.day =='Fri')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2
# 101       15.38  3.00  Female    Yes  Fri  Dinner     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2

# %%
# Female smokers on Thusday
Tips[(Tips.sex =='Female') & (Tips.smoker =='Yes') & (Tips.day =='Thur')]
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 191       19.81  4.19  Female    Yes  Thur  Lunch     2
# 197       43.11  5.00  Female    Yes  Thur  Lunch     4
# 198       13.00  2.00  Female    Yes  Thur  Lunch     2
# 201       12.74  2.01  Female    Yes  Thur  Lunch     2
# 202       13.00  2.00  Female    Yes  Thur  Lunch     2
# 203       16.40  2.50  Female    Yes  Thur  Lunch     2
# 205       16.47  3.23  Female    Yes  Thur  Lunch     3

# %%
# Male smokers on Sunday
Tips[(Tips.sex =='Male') & (Tips.smoker =='Yes') & (Tips.day =='Sun')]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2
# 173       31.85  3.18  Male    Yes  Sun  Dinner     2
# 174       16.82  4.00  Male    Yes  Sun  Dinner     2
# 175       32.90  3.11  Male    Yes  Sun  Dinner     2
# 176       17.89  2.00  Male    Yes  Sun  Dinner     2
# 177       14.48  2.00  Male    Yes  Sun  Dinner     2
# 179       34.63  3.55  Male    Yes  Sun  Dinner     2
# 180       34.65  3.68  Male    Yes  Sun  Dinner     4
# 181       23.33  5.65  Male    Yes  Sun  Dinner     2
# 182       45.35  3.50  Male    Yes  Sun  Dinner     3
# 183       23.17  6.50  Male    Yes  Sun  Dinner     4
# 184       40.55  3.00  Male    Yes  Sun  Dinner     2
# 187       30.46  2.00  Male    Yes  Sun  Dinner     5
# 189       23.10  4.00  Male    Yes  Sun  Dinner     3
# 190       15.69  1.50  Male    Yes  Sun  Dinner     2

# %%
# Male smokers on Saturday
Tips[(Tips.sex =='Male') & (Tips.smoker =='Yes') & (Tips.day =='Sat')]
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 56        38.01   3.00  Male    Yes  Sat  Dinner     4
# 58        11.24   1.76  Male    Yes  Sat  Dinner     2
# 60        20.29   3.21  Male    Yes  Sat  Dinner     2
# 61        13.81   2.00  Male    Yes  Sat  Dinner     2
# 62        11.02   1.98  Male    Yes  Sat  Dinner     2
# 63        18.29   3.76  Male    Yes  Sat  Dinner     4
# 69        15.01   2.09  Male    Yes  Sat  Dinner     2
# 76        17.92   3.08  Male    Yes  Sat  Dinner     2
# 105       15.36   1.64  Male    Yes  Sat  Dinner     2
# 106       20.49   4.06  Male    Yes  Sat  Dinner     2
# 107       25.21   4.29  Male    Yes  Sat  Dinner     2
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 171       15.81   3.16  Male    Yes  Sat  Dinner     2
# 206       26.59   3.41  Male    Yes  Sat  Dinner     3
# 207       38.73   3.00  Male    Yes  Sat  Dinner     4
# 208       24.27   2.03  Male    Yes  Sat  Dinner     2
# ...

# %%
# Male smokers on Friday
Tips[(Tips.sex =='Male') & (Tips.smoker =='Yes') & (Tips.day =='Fri')]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 90        28.97  3.00  Male    Yes  Fri  Dinner     2
# 95        40.17  4.73  Male    Yes  Fri  Dinner     4
# 96        27.28  4.00  Male    Yes  Fri  Dinner     2
# 97        12.03  1.50  Male    Yes  Fri  Dinner     2
# 98        21.01  3.00  Male    Yes  Fri  Dinner     2
# 220       12.16  2.20  Male    Yes  Fri   Lunch     2
# 222        8.58  1.92  Male    Yes  Fri   Lunch     1
# 224       13.42  1.58  Male    Yes  Fri   Lunch     2

# %%
# Male smokers on Thursday
Tips[(Tips.sex =='Male') & (Tips.smoker =='Yes') & (Tips.day =='Thur')]
# Out:
#      total_bill   tip   sex smoker   day   time  size
# 80        19.44  3.00  Male    Yes  Thur  Lunch     2
# 83        32.68  5.00  Male    Yes  Thur  Lunch     2
# 138       16.00  2.00  Male    Yes  Thur  Lunch     2
# 192       28.44  2.56  Male    Yes  Thur  Lunch     2
# 193       15.48  2.02  Male    Yes  Thur  Lunch     2
# 194       16.58  4.00  Male    Yes  Thur  Lunch     2
# 196       10.34  2.00  Male    Yes  Thur  Lunch     2
# 199       13.51  2.00  Male    Yes  Thur  Lunch     2
# 200       18.71  4.00  Male    Yes  Thur  Lunch     3
# 204       20.53  4.00  Male    Yes  Thur  Lunch     4

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
Tips['sex'].value_counts().plot(kind='bar')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
Tips['day'].value_counts().plot(kind='bar')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
Tips['time'].value_counts().plot(kind='bar')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
Tips['smoker'].value_counts().plot(kind='bar')

# %%
sns.barplot(x="sex", y="total_bill", hue="day", data=Tips)

# %%
sns.barplot(x="sex", y="total_bill", hue="time", data=Tips)

# %%
sns.barplot(x="sex", y="total_bill", hue="smoker", data=Tips)

# %%
sns.barplot(x="sex", y="tip", hue="day", data=Tips)

# %%
sns.barplot(x="sex", y="tip", hue="time", data=Tips)

# %%
sns.barplot(x="sex", y="tip", hue="smoker", data=Tips)

# %%
# Males only
MS=Tips[(Tips.sex =='Male') & (Tips.smoker =='Yes') & (Tips.day =='Thur')]
sns.barplot(x="sex", y="tip", hue="smoker", data=MS)

# %%
#Females only that give tip
sns.barplot(x="sex", y="tip", hue="smoker", data=A)

# %%
# Females only that pay total bill
sns.barplot(x="sex", y="total_bill", hue="smoker", data=A)

# %%
# Males only that pay total bill
sns.barplot(x="sex", y="total_bill", hue="smoker", data=B)

# %%
#Females that smoke
sns.barplot(x="sex", y="total_bill", hue="smoker", data=C)

# %%
#Females that do not smoke
sns.barplot(x="sex", y="total_bill", hue="smoker", data=D)

# %%
#Males that  smoke
sns.barplot(x="sex", y="total_bill", hue="smoker", data=E)

# %%
#Males that do not smoke
sns.barplot(x="sex", y="total_bill", hue="smoker", data=F)

# %%
# Males and Females that smoke
sns.barplot(x="sex", y="total_bill", hue="smoker", data=G)

# %%
# Males and Females that do not smoke
sns.barplot(x="sex", y="total_bill", hue="smoker", data=H)

# %%
# Males and Females that gave tip after Lunch and Dinner
sns.barplot(x="day", y="tip", hue="time", data=Tips)

# %%
# Males and Females that pay total bill after Lunch and Dinner
sns.barplot(x="day", y="total_bill", hue="time", data=Tips)

# %%
# Tayal bill on lunch on sunday
TB=Tips[(Tips.time =='Lunch') & (Tips.day =='Sun')][['total_bill','time','day']]
TB
# Out:
# Empty DataFrame
# Columns: [total_bill, time, day]
# Index: []

# %%
TB.shape
# Out:
# (0, 3)

# %%
# Tayal bill on Dinner on sunday
TB1=Tips[(Tips.time =='Dinner') & (Tips.day =='Sun')][['total_bill','time','day']]
TB1
# Out:
#      total_bill    time  day
# 0         16.99  Dinner  Sun
# 1         10.34  Dinner  Sun
# 2         21.01  Dinner  Sun
# 3         23.68  Dinner  Sun
# 4         24.59  Dinner  Sun
# ..          ...     ...  ...
# 186       20.90  Dinner  Sun
# 187       30.46  Dinner  Sun
# 188       18.15  Dinner  Sun
# 189       23.10  Dinner  Sun
# 190       15.69  Dinner  Sun
#
# [76 rows x 3 columns]

# %%
# Tatal bill for each day
sns.barplot(x="day", y="total_bill", hue="sex", data=Tips)

# %%
# Tip for each day
sns.barplot(x="day", y="tip", hue="sex", data=Tips)

# %%
Tips.groupby('sex')[["total_bill","tip","size"]].sum()
# Out:
#         total_bill     tip  size
# sex
# Male       3256.82  485.07   413
# Female     1570.95  246.51   214

# %%
Tips.groupby('day')[["total_bill","tip","size"]].sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
Tips.groupby('time')[["total_bill","tip","size"]].sum()
# Out:
#         total_bill     tip  size
# time
# Lunch      1167.47  185.51   164
# Dinner     3660.30  546.07   463

# %%
Tips.groupby('smoker')[["total_bill","tip","size"]].sum()
# Out:
#         total_bill     tip  size
# smoker
# Yes        1930.34  279.81   224
# No         2897.43  451.77   403

# %%
Tips.groupby(['sex','smoker'])[["total_bill","tip","size"]].sum()
# Out:
#                total_bill     tip  size
# sex    smoker
# Male   Yes        1337.07  183.07   150
#        No         1919.75  302.00   263
# Female Yes         593.27   96.74    74
#        No          977.68  149.77   140

# %%
Tips.groupby(['sex','time'])[["total_bill","tip","size"]].sum()
# Out:
#                total_bill     tip  size
# sex    time
# Male   Lunch       595.60   95.11    78
#        Dinner     2661.22  389.96   335
# Female Lunch       571.87   90.40    86
#        Dinner      999.08  156.11   128

# %%
Tips.groupby(['sex','day'])[["total_bill","tip","size"]].sum()
# Out:
#              total_bill     tip  size
# sex    day
# Male   Thur      561.44   89.41    73
#        Fri       198.57   26.93    21
#        Sat      1227.35  181.95   156
#        Sun      1269.46  186.78   163
# Female Thur      534.89   82.42    79
#        Fri       127.31   25.03    19
#        Sat       551.05   78.45    63
#        Sun       357.70   60.61    53

# %%
Tips.groupby(['time','day'])[["total_bill","tip","size"]].sum()
# Out:
#              total_bill     tip   size
# time   day
# Lunch  Thur     1077.55  168.83  150.0
#        Fri        89.92   16.68   14.0
#        Sat          NaN     NaN    NaN
#        Sun          NaN     NaN    NaN
# Dinner Thur       18.78    3.00    2.0
#        Fri       235.96   35.28   26.0
#        Sat      1778.40  260.40  219.0
#        Sun      1627.16  247.39  216.0

# %%
Tips.groupby(['smoker','day'])[["total_bill","tip","size"]].sum()
# Out:
#              total_bill     tip  size
# smoker day
# Yes    Thur      326.24   51.51    40
#        Fri       252.20   40.71    31
#        Sat       893.62  120.77   104
#        Sun       458.28   66.82    49
# No     Thur      770.09  120.32   112
#        Fri        73.68   11.25     9
#        Sat       884.78  139.63   115
#        Sun      1168.88  180.57   167

# %%
# No tatal bill and tip on daturday and sunday :
a=Tips[(Tips.day =='Sat') & (Tips.total_bill =='Sat')]
b=Tips[(Tips.day =='Sun') & (Tips.total_bill =='Sun')]
c=Tips[(Tips.day =='Sat') & (Tips.tip =='Sat')]
d=Tips[(Tips.day =='Sun') & (Tips.tip =='Sun')]
a,b,c,d
# Out:
# c:\users\victoria\appdata\local\programs\python\python37\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# (Empty DataFrame
#  Columns: [total_bill, tip, sex, smoker, day, time, size]
#  Index: [],
#  Empty DataFrame
#  Columns: [total_bill, tip, sex, smoker, day, time, size]
#  Index: [],
#  Empty DataFrame
#  Columns: [total_bill, tip, sex, smoker, day, time, size]
#  Index: [],
#  Empty DataFrame
#  Columns: [total_bill, tip, sex, smoker, day, time, size]
#  Index: [])

# %%
Tips[(Tips.day =='Sat')].head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 19       20.65  3.35    Male     No  Sat  Dinner     3
# 20       17.92  4.08    Male     No  Sat  Dinner     2
# 21       20.29  2.75  Female     No  Sat  Dinner     2
# 22       15.77  2.23  Female     No  Sat  Dinner     2
# 23       39.42  7.58    Male     No  Sat  Dinner     4

# %%
Tips[(Tips.day =='Sun')].tail()
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 186       20.90  3.5  Female    Yes  Sun  Dinner     3
# 187       30.46  2.0    Male    Yes  Sun  Dinner     5
# 188       18.15  3.5  Female    Yes  Sun  Dinner     3
# 189       23.10  4.0    Male    Yes  Sun  Dinner     3
# 190       15.69  1.5    Male    Yes  Sun  Dinner     2
